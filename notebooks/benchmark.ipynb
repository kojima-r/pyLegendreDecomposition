# %% [markdown]
# # テンソル多体分解の実装

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import itertools

import numpy as np

from LegendreDecomposition import LD as LD_cupy
from LegendreDecomposition.old import LD

# %% [markdown]
# # 実験

# %% [markdown]
# ## Random テンソルによる実験

# %% [markdown]
# ### ２次近似

# %%
N = 10
X = np.random.uniform(0, 0.1, size=(N, N, N, N))
X
# Out:
# array([[[[0.02456185, 0.07594729, 0.04632217, ..., 0.07911832,
#           0.04749621, 0.00108574],
#          [0.01785412, 0.0186851 , 0.02473015, ..., 0.06143376,
#           0.06415897, 0.01579581],
#          [0.0193518 , 0.06048574, 0.09015333, ..., 0.01439587,
#           0.07400735, 0.07780935],
#          ...,
#          [0.05881657, 0.06845316, 0.05433782, ..., 0.03826952,
#           0.09360572, 0.05893505],
#          [0.0669766 , 0.0986031 , 0.0405482 , ..., 0.04040596,
#           0.02977316, 0.06650399],
#          [0.04605704, 0.08201341, 0.04559612, ..., 0.00542682,
#           0.06055674, 0.01441761]],
#
#         [[0.02331532, 0.03095989, 0.09264013, ..., 0.038823  ,
#           0.08483852, 0.09208708],
#          [0.03489452, 0.04178505, 0.05531045, ..., 0.06053565,
#           0.0524742 , 0.05791717],
#          [0.09309412, 0.03150101, 0.02757887, ..., 0.08750837,
#           0.02062332, 0.038026  ],
#          ...,
#          [0.03883839, 0.09601238, 0.05670824, ..., 0.03814517,
#           0.0906253 , 0.03059726],
#          [0.03419395, 0.05932174, 0.00986071, ..., 0.06313744,
#           0.0074397 , 0.03387844],
#          [0.05913583, 0.0146911 , 0.07001456, ..., 0.09484833,
#           0.03152761, 0.07371351]],
#
#         [[0.06468883, 0.05256342, 0.04935875, ..., 0.0228912 ,
#           0.00177612, 0.00262546],
#          [0.02461112, 0.02085159, 0.05165925, ..., 0.0328048 ,
#           0.01817576, 0.07287184],
#          [0.07406687, 0.06944275, 0.00249926, ..., 0.04370306,
#           0.06444244, 0.05620431],
#          ...,
#          [0.08852073, 0.07146232, 0.01594322, ..., 0.03934302,
#           0.02857697, 0.06600931],
#          [0.07389545, 0.01386595, 0.0344523 , ..., 0.07074795,
#           0.05917702, 0.09277668],
#          [0.07935789, 0.08385466, 0.03697806, ..., 0.07913356,
#           0.04740756, 0.04227583]],
#
#         ...,
#
#         [[0.08340037, 0.06424378, 0.07133053, ..., 0.04323209,
#           0.03642976, 0.04677239],
#          [0.05772961, 0.04221675, 0.09404699, ..., 0.06029831,
#           0.0402288 , 0.00753746],
#          [0.00679913, 0.02318172, 0.08069026, ..., 0.00770606,
#           0.04358541, 0.07883742],
#          ...,
#          [0.01899688, 0.03962966, 0.01712345, ..., 0.02748221,
#           0.03282403, 0.0379432 ],
#          [0.074423  , 0.01131572, 0.09537737, ..., 0.04134833,
#           0.00106307, 0.03123466],
#          [0.07694428, 0.03625271, 0.06094475, ..., 0.06367877,
#           0.00506547, 0.00951853]],
#
#         [[0.01987695, 0.01008195, 0.0993798 , ..., 0.0839023 ,
#           0.08653382, 0.06607476],
#          [0.02718889, 0.01349989, 0.03417297, ..., 0.06760671,
#           0.05615776, 0.0617029 ],
#          [0.03494487, 0.00942185, 0.03595512, ..., 0.03788096,
#           0.05351056, 0.08357218],
#          ...,
#          [0.03063237, 0.05430541, 0.08926685, ..., 0.09279872,
#           0.08611484, 0.0177144 ],
#          [0.03555687, 0.01035925, 0.03242324, ..., 0.08939063,
#           0.02505578, 0.03796884],
#          [0.09144215, 0.03048795, 0.02070267, ..., 0.05982742,
#           0.00841967, 0.0254254 ]],
#
#         [[0.01464132, 0.0378053 , 0.03623811, ..., 0.06444077,
#           0.08077891, 0.05965461],
#          [0.07238048, 0.00039061, 0.05886843, ..., 0.01453966,
#           0.00077666, 0.08118161],
#          [0.08998917, 0.04519156, 0.02473469, ..., 0.09917302,
#           0.09292265, 0.04457433],
#          ...,
#          [0.07245756, 0.08794508, 0.0670822 , ..., 0.0286217 ,
#           0.03270084, 0.02651992],
#          [0.00184818, 0.05053499, 0.01517719, ..., 0.02605001,
#           0.03540554, 0.04101839],
#          [0.06227369, 0.03631465, 0.04602947, ..., 0.05342635,
#           0.0324265 , 0.03917089]]],
#
#
#        [[[0.09669104, 0.05816192, 0.07051683, ..., 0.01751027,
#           0.08093802, 0.05883432],
#          [0.03783659, 0.03721587, 0.08540756, ..., 0.02667989,
#           0.0283783 , 0.07317512],
#          [0.09862799, 0.01731855, 0.09859415, ..., 0.05150492,
#           0.05919837, 0.01668946],
#          ...,
#          [0.03306783, 0.07693577, 0.03360079, ..., 0.0414137 ,
#           0.05400245, 0.05563312],
#          [0.05350182, 0.08048742, 0.05764056, ..., 0.00724037,
#           0.08772647, 0.01764248],
#          [0.08574077, 0.01376926, 0.08700187, ..., 0.09867793,
#           0.05033014, 0.03777911]],
#
#         [[0.04992897, 0.04981443, 0.03339593, ..., 0.09541004,
#           0.00425575, 0.09461693],
#          [0.00132535, 0.01847888, 0.05372561, ..., 0.04563901,
#           0.05110421, 0.03436947],
#          [0.09198586, 0.0741984 , 0.02221361, ..., 0.08477036,
#           0.01687844, 0.0411512 ],
#          ...,
#          [0.09791815, 0.0099837 , 0.04761466, ..., 0.07932707,
#           0.04497821, 0.04077519],
#          [0.03467763, 0.05773402, 0.07992479, ..., 0.06180055,
#           0.00583132, 0.04306247],
#          [0.02583185, 0.0328821 , 0.07043614, ..., 0.08107191,
#           0.03893765, 0.04203675]],
#
#         [[0.04916101, 0.04613277, 0.06227631, ..., 0.08706622,
#           0.04417739, 0.0910833 ],
#          [0.09757042, 0.00898824, 0.09928899, ..., 0.01383899,
#           0.00080779, 0.0009797 ],
#          [0.0270025 , 0.02276707, 0.04701512, ..., 0.01925177,
#           0.08565769, 0.04528081],
#          ...,
#          [0.08260685, 0.09408659, 0.01123432, ..., 0.03409493,
#           0.02433495, 0.0642308 ],
#          [0.07454931, 0.07659654, 0.02236258, ..., 0.02176178,
#           0.04226994, 0.06730439],
#          [0.00571247, 0.08717277, 0.0231625 , ..., 0.06450752,
#           0.02242817, 0.09545164]],
#
#         ...,
#
#         [[0.06790549, 0.06748154, 0.00251459, ..., 0.09080682,
#           0.0515705 , 0.06507061],
#          [0.07507327, 0.07322721, 0.04676592, ..., 0.05664715,
#           0.07364713, 0.08636469],
#          [0.08981849, 0.03079914, 0.0847425 , ..., 0.06923403,
#           0.02239397, 0.03933894],
#          ...,
#          [0.05983093, 0.00854843, 0.03818806, ..., 0.04893495,
#           0.07577748, 0.09919885],
#          [0.01887269, 0.04924145, 0.06341588, ..., 0.08234572,
#           0.03611859, 0.0811468 ],
#          [0.0077547 , 0.07911644, 0.05686853, ..., 0.07339942,
#           0.08628498, 0.04594168]],
#
#         [[0.0128136 , 0.05420047, 0.02155627, ..., 0.03456089,
#           0.09952494, 0.08244046],
#          [0.00403142, 0.02712513, 0.04986193, ..., 0.05697884,
#           0.03846317, 0.07775392],
#          [0.07744254, 0.05816724, 0.0397918 , ..., 0.08371601,
#           0.08603188, 0.01208679],
#          ...,
#          [0.033823  , 0.00959226, 0.07799767, ..., 0.06609337,
#           0.01483796, 0.00138036],
#          [0.06561836, 0.03459252, 0.04061973, ..., 0.00240822,
#           0.08872678, 0.04025479],
#          [0.05587784, 0.07484649, 0.01846878, ..., 0.0885974 ,
#           0.01043115, 0.01820857]],
#
#         [[0.05327922, 0.09126238, 0.02605894, ..., 0.01964652,
#           0.03513947, 0.01728229],
#          [0.09332653, 0.07847873, 0.01808708, ..., 0.01881314,
#           0.03548207, 0.09945263],
#          [0.01823457, 0.09374158, 0.0721356 , ..., 0.03606949,
#           0.03160578, 0.03096419],
#          ...,
#          [0.03748303, 0.0045323 , 0.073203  , ..., 0.04383964,
#           0.09610419, 0.07245524],
#          [0.04644944, 0.04809363, 0.09413744, ..., 0.0404424 ,
#           0.0510257 , 0.02255887],
#          [0.09169392, 0.04912947, 0.04172607, ..., 0.02416208,
#           0.02160805, 0.0642282 ]]],
#
#
#        [[[0.09771124, 0.09030095, 0.05755229, ..., 0.05172535,
#           0.03725948, 0.04645968],
#          [0.02830742, 0.0182344 , 0.03606557, ..., 0.02922241,
#           0.02996011, 0.08683228],
#          [0.03950467, 0.07978177, 0.03071529, ..., 0.07130793,
#           0.05377875, 0.06512114],
#          ...,
#          [0.07225594, 0.04186433, 0.00260078, ..., 0.00161   ,
#           0.02594444, 0.08934483],
#          [0.06649796, 0.04497949, 0.05633536, ..., 0.08042881,
#           0.02242876, 0.08825187],
#          [0.08815064, 0.03662058, 0.08962246, ..., 0.01906141,
#           0.00788632, 0.0581457 ]],
#
#         [[0.05143149, 0.00203408, 0.00344201, ..., 0.02660522,
#           0.03833099, 0.09560974],
#          [0.06167202, 0.014706  , 0.04514201, ..., 0.07804509,
#           0.00636009, 0.09827896],
#          [0.05352068, 0.06225206, 0.04111507, ..., 0.03221625,
#           0.0132366 , 0.04977866],
#          ...,
#          [0.06104608, 0.00559704, 0.08430215, ..., 0.003888  ,
#           0.01413165, 0.06466762],
#          [0.08884071, 0.02783255, 0.0874335 , ..., 0.07209852,
#           0.07552613, 0.01930273],
#          [0.09952745, 0.06355824, 0.00877849, ..., 0.05788257,
#           0.08137616, 0.06173629]],
#
#         [[0.01415626, 0.07669787, 0.03289874, ..., 0.0133905 ,
#           0.06952541, 0.03007985],
#          [0.02917205, 0.02480112, 0.05611663, ..., 0.07359776,
#           0.05938837, 0.00523027],
#          [0.09350832, 0.01768273, 0.08415637, ..., 0.09141771,
#           0.07966394, 0.03913083],
#          ...,
#          [0.07496815, 0.0023612 , 0.05933192, ..., 0.05377956,
#           0.05046056, 0.01242879],
#          [0.08284774, 0.04343157, 0.04714464, ..., 0.01433713,
#           0.06185944, 0.09361799],
#          [0.06301937, 0.01719949, 0.04416442, ..., 0.05885962,
#           0.09700737, 0.08658918]],
#
#         ...,
#
#         [[0.03374109, 0.0165282 , 0.09089567, ..., 0.04882234,
#           0.03714335, 0.06205243],
#          [0.06559256, 0.01950545, 0.02887755, ..., 0.06825798,
#           0.09215823, 0.07969098],
#          [0.04252241, 0.07983073, 0.03317563, ..., 0.09956531,
#           0.05515002, 0.03422095],
#          ...,
#          [0.04254378, 0.07746406, 0.047756  , ..., 0.04002332,
#           0.00818428, 0.03666753],
#          [0.07317683, 0.07086431, 0.06104609, ..., 0.03821903,
#           0.04757827, 0.03586711],
#          [0.05145346, 0.01732835, 0.02645101, ..., 0.0988632 ,
#           0.03190558, 0.00458316]],
#
#         [[0.01414878, 0.05629954, 0.0830147 , ..., 0.0424701 ,
#           0.07588034, 0.02752324],
#          [0.05388409, 0.09914804, 0.05686051, ..., 0.0966603 ,
#           0.03645763, 0.00247948],
#          [0.03745551, 0.08853721, 0.08365181, ..., 0.02550166,
#           0.05249198, 0.00443406],
#          ...,
#          [0.02525986, 0.04288314, 0.08832283, ..., 0.07163543,
#           0.09222536, 0.09640209],
#          [0.06418559, 0.08433703, 0.01583414, ..., 0.06476437,
#           0.05517023, 0.01809938],
#          [0.04586487, 0.00250058, 0.07356889, ..., 0.02074696,
#           0.05889508, 0.0898208 ]],
#
#         [[0.08230008, 0.09669983, 0.09753404, ..., 0.08018322,
#           0.0797496 , 0.07267976],
#          [0.04818937, 0.00037975, 0.09608654, ..., 0.09048572,
#           0.07227597, 0.02004195],
#          [0.02194577, 0.04601697, 0.0712571 , ..., 0.04500123,
#           0.00444116, 0.00384002],
#          ...,
#          [0.01178433, 0.06371825, 0.08635393, ..., 0.03899249,
#           0.01545803, 0.00359465],
#          [0.01687265, 0.05437723, 0.09576561, ..., 0.08117769,
#           0.03450275, 0.05122341],
#          [0.04100921, 0.01748388, 0.0319501 , ..., 0.07619837,
#           0.01260854, 0.00797243]]],
#
#
#        ...,
#
#
#        [[[0.00273413, 0.02835182, 0.01777365, ..., 0.04896669,
#           0.02946574, 0.07214957],
#          [0.07527246, 0.06290068, 0.09160222, ..., 0.05361307,
#           0.07153915, 0.08409686],
#          [0.08336342, 0.00230149, 0.07273714, ..., 0.00851518,
#           0.09492403, 0.05266065],
#          ...,
#          [0.02149998, 0.07958795, 0.08650645, ..., 0.07515614,
#           0.04287663, 0.0149216 ],
#          [0.0402189 , 0.01425535, 0.05826868, ..., 0.02998343,
#           0.00488348, 0.02458752],
#          [0.03994416, 0.08241068, 0.00678306, ..., 0.02677798,
#           0.0250597 , 0.04580992]],
#
#         [[0.01374035, 0.04503066, 0.0228438 , ..., 0.00795817,
#           0.07706117, 0.05970736],
#          [0.06324365, 0.0469034 , 0.03565755, ..., 0.01538158,
#           0.02991019, 0.08669457],
#          [0.01741639, 0.06951851, 0.01123578, ..., 0.01671082,
#           0.05121774, 0.0901748 ],
#          ...,
#          [0.09423456, 0.05256996, 0.06346896, ..., 0.01255132,
#           0.09754944, 0.08303973],
#          [0.0261986 , 0.00477796, 0.01565679, ..., 0.08432692,
#           0.00245221, 0.05729084],
#          [0.00313316, 0.04421201, 0.01025497, ..., 0.04085059,
#           0.0635794 , 0.01070431]],
#
#         [[0.01028063, 0.07490598, 0.05262632, ..., 0.0388088 ,
#           0.05116443, 0.02594029],
#          [0.09668023, 0.05679961, 0.08564635, ..., 0.09861375,
#           0.03469204, 0.00996423],
#          [0.05764127, 0.0407134 , 0.01413057, ..., 0.05437926,
#           0.08856376, 0.01647977],
#          ...,
#          [0.02975214, 0.05983534, 0.00526454, ..., 0.00802166,
#           0.06072816, 0.09135215],
#          [0.08030949, 0.00474539, 0.06468594, ..., 0.06606673,
#           0.01315393, 0.0712697 ],
#          [0.03896012, 0.08339893, 0.02245906, ..., 0.01534076,
#           0.00055311, 0.09890156]],
#
#         ...,
#
#         [[0.02201552, 0.01941614, 0.07615972, ..., 0.02348737,
#           0.03422112, 0.03471121],
#          [0.0563756 , 0.07245732, 0.02738392, ..., 0.05140936,
#           0.00383244, 0.08853041],
#          [0.07052252, 0.0129257 , 0.05019139, ..., 0.06698328,
#           0.06856517, 0.03685971],
#          ...,
#          [0.01052226, 0.09234965, 0.09548277, ..., 0.01995421,
#           0.07562117, 0.0835985 ],
#          [0.00746257, 0.09734071, 0.00807137, ..., 0.00392181,
#           0.05861091, 0.01948393],
#          [0.0602089 , 0.04716953, 0.08231735, ..., 0.07839025,
#           0.0891378 , 0.04699491]],
#
#         [[0.08911333, 0.04140295, 0.0241113 , ..., 0.0935971 ,
#           0.0195536 , 0.08648579],
#          [0.09467107, 0.05220595, 0.0498261 , ..., 0.09752029,
#           0.07381741, 0.06046461],
#          [0.09405897, 0.09463347, 0.05133557, ..., 0.09844839,
#           0.00515787, 0.05580602],
#          ...,
#          [0.09551305, 0.06508996, 0.09103223, ..., 0.07462648,
#           0.04472493, 0.09350544],
#          [0.00210656, 0.09058858, 0.07685334, ..., 0.09941112,
#           0.07226436, 0.05232013],
#          [0.06469809, 0.033528  , 0.0954426 , ..., 0.03529372,
#           0.01340066, 0.07226902]],
#
#         [[0.0471376 , 0.034396  , 0.05141232, ..., 0.01528869,
#           0.06288517, 0.08579046],
#          [0.07239151, 0.01942663, 0.0146181 , ..., 0.04063343,
#           0.03240898, 0.05420091],
#          [0.09157179, 0.0019862 , 0.03798612, ..., 0.03727543,
#           0.06290702, 0.00323115],
#          ...,
#          [0.02107655, 0.08740037, 0.05917661, ..., 0.09650946,
#           0.09081189, 0.04933077],
#          [0.02524748, 0.04057865, 0.0999604 , ..., 0.00569617,
#           0.00155389, 0.00166595],
#          [0.07475453, 0.01659905, 0.07869342, ..., 0.04409334,
#           0.08006913, 0.09216468]]],
#
#
#        [[[0.0808349 , 0.05623886, 0.0368538 , ..., 0.09653413,
#           0.02097209, 0.09062114],
#          [0.08446012, 0.01104298, 0.01913476, ..., 0.08080501,
#           0.02772135, 0.04576405],
#          [0.08465394, 0.0673022 , 0.00846015, ..., 0.07767817,
#           0.04194478, 0.04827027],
#          ...,
#          [0.05432882, 0.01928867, 0.0446167 , ..., 0.08460154,
#           0.0546146 , 0.07468253],
#          [0.0761729 , 0.04321706, 0.0150944 , ..., 0.02063695,
#           0.04654395, 0.06606492],
#          [0.06438531, 0.06594637, 0.00479296, ..., 0.04748606,
#           0.05537243, 0.03286689]],
#
#         [[0.01664271, 0.09961841, 0.06720458, ..., 0.05870988,
#           0.051963  , 0.07458818],
#          [0.02373734, 0.09320341, 0.09009826, ..., 0.07721857,
#           0.09486887, 0.06938693],
#          [0.03962217, 0.01737882, 0.00109812, ..., 0.0897415 ,
#           0.02762814, 0.03358212],
#          ...,
#          [0.08135715, 0.01658927, 0.06225657, ..., 0.08644154,
#           0.03076708, 0.01688347],
#          [0.02062073, 0.03984546, 0.07130001, ..., 0.04701856,
#           0.04569449, 0.01611698],
#          [0.01717822, 0.06188021, 0.004528  , ..., 0.09686961,
#           0.09478767, 0.0145469 ]],
#
#         [[0.09894625, 0.01906094, 0.02158504, ..., 0.06081176,
#           0.08243066, 0.03492498],
#          [0.05155495, 0.0154779 , 0.0744908 , ..., 0.09981327,
#           0.00141607, 0.00052397],
#          [0.02611139, 0.06320736, 0.03690409, ..., 0.02756586,
#           0.03772365, 0.01132934],
#          ...,
#          [0.01570154, 0.02137539, 0.09668547, ..., 0.05501009,
#           0.06406987, 0.0802533 ],
#          [0.02261346, 0.00344161, 0.08279499, ..., 0.04270665,
#           0.0469609 , 0.04756573],
#          [0.03574312, 0.08504821, 0.08206424, ..., 0.03560934,
#           0.05456095, 0.09559785]],
#
#         ...,
#
#         [[0.05827092, 0.05106818, 0.03922571, ..., 0.00046959,
#           0.02372189, 0.02652259],
#          [0.04703585, 0.08839844, 0.08080064, ..., 0.08279666,
#           0.03834126, 0.04034042],
#          [0.01721987, 0.05121927, 0.0050536 , ..., 0.03934562,
#           0.06490703, 0.07454993],
#          ...,
#          [0.02256683, 0.02649127, 0.0598597 , ..., 0.01922387,
#           0.02210789, 0.09714787],
#          [0.0569038 , 0.08902104, 0.07881453, ..., 0.00400084,
#           0.00243762, 0.01549283],
#          [0.09042918, 0.08022951, 0.06324923, ..., 0.01475805,
#           0.04718183, 0.00158315]],
#
#         [[0.09651188, 0.09304768, 0.05642221, ..., 0.08287932,
#           0.05709875, 0.09506545],
#          [0.01611658, 0.0464761 , 0.04086398, ..., 0.07940217,
#           0.03816103, 0.06950562],
#          [0.01549362, 0.08104051, 0.01725099, ..., 0.09960039,
#           0.00269664, 0.0599842 ],
#          ...,
#          [0.01155801, 0.05694801, 0.0745363 , ..., 0.03888102,
#           0.02594024, 0.09547327],
#          [0.0162706 , 0.02581587, 0.00662514, ..., 0.09456308,
#           0.02321018, 0.00616341],
#          [0.09780224, 0.05163939, 0.01026179, ..., 0.02397298,
#           0.03157888, 0.07430665]],
#
#         [[0.01393718, 0.03465281, 0.0814914 , ..., 0.04406376,
#           0.02095768, 0.02480928],
#          [0.06659081, 0.04819441, 0.02621992, ..., 0.09485345,
#           0.07074104, 0.07136218],
#          [0.02190077, 0.01102158, 0.0814831 , ..., 0.03201297,
#           0.05326448, 0.08285992],
#          ...,
#          [0.07129577, 0.03340264, 0.07695727, ..., 0.03530933,
#           0.05172556, 0.06962126],
#          [0.07753859, 0.0639291 , 0.05033079, ..., 0.03402217,
#           0.0235617 , 0.02295376],
#          [0.09355797, 0.05933192, 0.0700892 , ..., 0.07816534,
#           0.06274016, 0.02425005]]],
#
#
#        [[[0.00155808, 0.0596615 , 0.06497046, ..., 0.01548456,
#           0.02086094, 0.00259899],
#          [0.0535112 , 0.09867551, 0.02902036, ..., 0.09880723,
#           0.07874646, 0.05609755],
#          [0.03347185, 0.06771716, 0.01740308, ..., 0.02398529,
#           0.03238283, 0.00326815],
#          ...,
#          [0.05644976, 0.01071094, 0.00856194, ..., 0.08453835,
#           0.09151049, 0.07333293],
#          [0.08586061, 0.08937952, 0.0019172 , ..., 0.08998454,
#           0.01205122, 0.06956104],
#          [0.04924518, 0.00652451, 0.09478229, ..., 0.0498387 ,
#           0.04320197, 0.09872716]],
#
#         [[0.08406455, 0.0697363 , 0.09724242, ..., 0.01374467,
#           0.03650325, 0.07135299],
#          [0.09535661, 0.01516232, 0.01666018, ..., 0.07650562,
#           0.06711374, 0.08026126],
#          [0.04792242, 0.02645017, 0.01629841, ..., 0.08476236,
#           0.04786023, 0.07937772],
#          ...,
#          [0.03960471, 0.00124049, 0.02936302, ..., 0.00913138,
#           0.01419397, 0.01145462],
#          [0.01167319, 0.00766925, 0.05254772, ..., 0.07861105,
#           0.01770758, 0.0924166 ],
#          [0.08910453, 0.01636216, 0.00060911, ..., 0.0656927 ,
#           0.04620231, 0.07768163]],
#
#         [[0.05630991, 0.02907364, 0.07768211, ..., 0.01637497,
#           0.0663731 , 0.06501011],
#          [0.03074746, 0.02099516, 0.09393533, ..., 0.04684653,
#           0.009297  , 0.09388837],
#          [0.07039871, 0.01539396, 0.04849391, ..., 0.04460833,
#           0.04958349, 0.05529341],
#          ...,
#          [0.02890507, 0.08354592, 0.04957009, ..., 0.05099424,
#           0.01505513, 0.01075957],
#          [0.0766112 , 0.08547943, 0.0077998 , ..., 0.09288941,
#           0.05081424, 0.07652925],
#          [0.07531199, 0.07163537, 0.01676121, ..., 0.06840378,
#           0.00645862, 0.03726491]],
#
#         ...,
#
#         [[0.00735685, 0.0455394 , 0.0819163 , ..., 0.02669469,
#           0.09665446, 0.05909152],
#          [0.06566095, 0.06717413, 0.01363073, ..., 0.04545456,
#           0.06991757, 0.02956509],
#          [0.00146073, 0.02310469, 0.09313075, ..., 0.03488337,
#           0.02205507, 0.06557812],
#          ...,
#          [0.07525361, 0.01732362, 0.03019716, ..., 0.01597673,
#           0.00168421, 0.03263715],
#          [0.04309397, 0.05314177, 0.0253326 , ..., 0.03552082,
#           0.04735362, 0.01783438],
#          [0.06647943, 0.06634843, 0.01667796, ..., 0.04072762,
#           0.08838903, 0.08939432]],
#
#         [[0.00854489, 0.02873827, 0.09004749, ..., 0.07191044,
#           0.07661089, 0.0522063 ],
#          [0.0523048 , 0.06622264, 0.01376932, ..., 0.07187173,
#           0.0551406 , 0.07554223],
#          [0.0998595 , 0.09522062, 0.08853597, ..., 0.05155873,
#           0.09510313, 0.06987489],
#          ...,
#          [0.094092  , 0.01303532, 0.06045253, ..., 0.03949189,
#           0.02713837, 0.08816113],
#          [0.02222698, 0.03479006, 0.08429787, ..., 0.09227349,
#           0.01752287, 0.0725219 ],
#          [0.00804452, 0.01630274, 0.05884566, ..., 0.07330811,
#           0.02479215, 0.0180833 ]],
#
#         [[0.00533842, 0.03396269, 0.09013068, ..., 0.07679598,
#           0.05373497, 0.02888672],
#          [0.0399618 , 0.08226817, 0.08681815, ..., 0.01156545,
#           0.09773376, 0.02337441],
#          [0.0439837 , 0.09876204, 0.02462209, ..., 0.02673807,
#           0.0279668 , 0.02604097],
#          ...,
#          [0.09119198, 0.08740895, 0.01183034, ..., 0.08364018,
#           0.06137467, 0.0302971 ],
#          [0.04512744, 0.09180092, 0.09321292, ..., 0.03913678,
#           0.05679102, 0.05544401],
#          [0.00614786, 0.05331392, 0.04785734, ..., 0.04619857,
#           0.0622016 , 0.01260362]]]])

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, order=2, verbose=False)
# Out:
# 502 ms ± 4.09 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit LD_cupy(X, order=2, gpu=False, verbose=False)
# Out:
# 32 ms ± 4.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit LD_cupy(X, order=2, verbose=False)
# Out:
# 24.3 ms ± 1.12 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit LD_cupy(X, order=2, verbose=False, dtype=np.float32)
# Out:
# 13.7 ms ± 1.67 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 画像テンソルによる実験

# %% [markdown]
# ### 2 次近似

# %%
from pathlib import Path

import matplotlib.pyplot as plt
from PIL import Image

X = []
for k in range(1, 5):
    # ファイル名、パス
    file_name = Path("..") / "tests" / "resources" / "coil-100/obj{}__0.png".format(k)
    img = Image.open(file_name)
    img = img.resize((32, 32))
    array_obj = np.asarray(img)
    # print(array_obj.shape)
    # 画像の表示
    # plt.imshow(array_obj)
    # plt.show()
    X.append(array_obj)
X = np.array(X)
X = (X + 1) / 256.0
X.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 10
#       7 for k in range(1, 5):
#       8     # ファイル名、パス
#       9     file_name = Path("..") / "tests" / "resources" / "coil-100/obj{}__0.png".format(k)
# ---> 10     img = Image.open(file_name)
#      11     img = img.resize((32, 32))
#      12     array_obj = np.asarray(img)
#
# File ~/work/manybodytensor/.venv/lib/python3.10/site-packages/PIL/Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/giprayogo/work/manybodytensor/tests/resources/coil-100/obj1__0.png'

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, order=2, verbose=False)
# Out:
# 11.8 s ± 21.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, order=2, gpu=False, verbose=False)
# Out:
# 368 ms ± 12.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, order=2, verbose=False)
# Out:
# 110 ms ± 968 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, order=2, dtype=np.float32, verbose=False)
# Out:
# 74.3 ms ± 271 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### リング分解による実装

# %%
# ring decomposition
def constraint(I):
    I = np.array(I)
    idx = np.where(I)[0]
    if len(idx) == 2:
        if idx[1] - idx[0] == 1 or (idx[1] == 3 and idx[0] == 0):
            return True
        else:
            return False
    else:
        return False


B = [
    I
    for I in itertools.product(*[list(range(X.shape[d])) for d in range(len(X.shape))])
    if constraint(I)
]

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, B, verbose=False)
# Out:
# 3.4 s ± 5.96 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, B, gpu=False, verbose=False)
# Out:
# 107 ms ± 5.85 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, B, verbose=False)
# Out:
# 21.1 ms ± 111 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, B, verbose=False, dtype=np.float32)
# Out:
# 8.41 ms ± 8.14 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### 依存関係 B を設計

# %%
# ２次の近似から、index - channel 結合を切断する
def constraint(I):
    I = np.array(I)
    if np.sum(I != 0) <= 2:
        if I[0] != 0 and I[3] != 0:
            return False
        else:
            return True
    else:
        return False


B = [
    I
    for I in itertools.product(*[list(range(X.shape[d])) for d in range(len(X.shape))])
    if constraint(I)
]

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, B, verbose=False)
# Out:
# 9.56 s ± 257 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, B, gpu=False, verbose=False)
# Out:
# 282 ms ± 60.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, B, verbose=False)
# Out:
# 49.9 ms ± 37.9 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(X, B, verbose=False, dtype=np.float32)
# Out:
# 18.2 ms ± 6.15 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## MovieLens データセットによる実験

# %%
import pandas as pd

df = pd.read_csv("ml-latest-small/movies.csv")

genres_set = set()
for i, r in df.iterrows():
    for el in r["genres"].split("|"):
        genres_set.add(el)
genres_list = list(genres_set)

# %%
edges_mg_dict = {}
mid_dict = {}
for i, r in df.iterrows():
    for el in r["genres"].split("|"):
        genres_set.add(el)
        j = genres_list.index(el)
        m = int(r["movieId"])
        if m not in mid_dict:
            mid_dict[m] = len(mid_dict)
        if mid_dict[m] not in edges_mg_dict:
            edges_mg_dict[mid_dict[m]] = []
        edges_mg_dict[mid_dict[m]].append(j)

# %%
df = pd.read_csv("ml-latest-small/ratings.csv")
edges = []

for i, r in df.iterrows():
    m = int(r["movieId"])
    if m in mid_dict:
        for g in edges_mg_dict[mid_dict[m]]:
            e = (int(r["userId"]) - 1, mid_dict[m], g, r["rating"])
            edges.append(e)

# %%
u_max = max([e[0] for e in edges])
m_max = max([e[1] for e in edges])
g_max = max([e[2] for e in edges])

print(u_max, m_max, g_max)
# Out:
# 609 9741 19

# %%
import numpy as np

M = np.zeros((u_max + 1, m_max + 1, g_max + 1))
for u, m, g, r in edges:
    M[u, m, g] = r

# %%
M_ = M[:10, :10, :]

# %%
M_.shape
# Out:
# (10, 10, 20)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(M_, order=2, eps=1.0e-10, verbose=False)
# Out:
# 416 ms ± 1.07 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(M_, order=2, eps=1.0e-10, gpu=False, verbose=False)
# Out:
# 32.2 ms ± 2.66 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(M_, order=2, eps=1.0e-10, verbose=False)
# Out:
# 13.8 ms ± 14.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD_cupy(M_, order=2, eps=1.0e-10, verbose=False, dtype=np.float32)
# Out:
# 11.8 ms ± 20.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## larger and larger random tensor

# %%
N = 10
X = np.random.uniform(0, 0.1, size=(N, N, N, N))

# %%
# %timeit LD(X, order=2, verbose=False)
# %timeit LD_cupy(X, order=2, gpu=False, verbose=False)
# %timeit LD_cupy(X, order=2, verbose=False)
# Out:
# 504 ms ± 7.38 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 22.5 ms ± 304 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 7.04 ms ± 25.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
N = 12
X = np.random.uniform(0, 0.1, size=(N, N, N, N))

# %%
# %timeit LD(X, order=2, verbose=False)
# %timeit LD_cupy(X, order=2, gpu=False, verbose=False)
# %timeit LD_cupy(X, order=2, verbose=False)
# Out:
# 1.02 s ± 747 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 52.2 ms ± 2.62 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 9.14 ms ± 22.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
N = 14
X = np.random.uniform(0, 0.1, size=(N, N, N, N))

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, order=2, verbose=False)
# %timeit LD_cupy(X, order=2, gpu=False, verbose=False)
# %timeit LD_cupy(X, order=2, verbose=False)
# Out:
# 2.74 s ± 4.96 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 134 ms ± 39.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 19.2 ms ± 51.8 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
N = 17
X = np.random.uniform(0, 0.1, size=(N, N, N, N))

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, order=2, verbose=False)
# %timeit LD_cupy(X, order=2, gpu=False, verbose=False)
# %timeit LD_cupy(X, order=2, verbose=False)
# Out:
# 8.08 s ± 31.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 305 ms ± 7.96 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 40.8 ms ± 19.5 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
N = 20
X = np.random.uniform(0, 0.1, size=(N, N, N, N))

# %%
# %timeit all_history_kl, scaleX, Q, Hq = LD(X, order=2, verbose=False)
# %timeit LD_cupy(X, order=2, gpu=False, verbose=False)
# %timeit LD_cupy(X, order=2, verbose=False)
# Out:
# 31.1 s ± 107 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 1.18 s ± 66.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 140 ms ± 21.3 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
X = np.random.uniform(0, 0.1, size=(30, 30, 30, 30, 30))
X.shape
# Out:
# (30, 30, 30, 30, 30)

# %%
all_history_kl, scaleX, Q, Hq = LD_cupy(X, order=2, verbose=True)
# Out:
# iter= 0 kl= 0.19309474471629862 mse= 5.643692895071144e-16
# iter= 1 kl= 237.6959260464662 mse= 1.000005641734787e-10
# iter= 2 kl= 237.69592604453695 mse= 1.0000056417348576e-10

# %%
X = np.random.uniform(0, 0.1, size=(20, 20, 20, 20, 20, 20))
X.shape
# Out:
# (20, 20, 20, 20, 20, 20)

# %%
all_history_kl, scaleX, Q, Hq = LD_cupy(X, order=2, verbose=True)
# Out:
# iter= 0 kl= 0.19300479988028052 mse= 8.132596317528895e-17
# iter= 1 kl= 633.7299752973898 mse= 1.0000008131882626e-10
# iter= 2 kl= 633.729975297318 mse= 1.0000008131882638e-10
